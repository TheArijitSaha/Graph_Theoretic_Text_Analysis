# %%
import networkx as nx
from text_filterer import formTokens
from n_gram_graph import gram3Generator
from clustering_coefficient import wordsByClusteringCoefficient
from betweenness_centrality import wordsByBetweennessCentrality
from degree_centrality import wordsByDegreeCentrality
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
G=gram3Generator('FilteredTexts/Sonar_Kella.txt')

# %%
wordsByClusteringCoefficient(G)
# Out:
# CLUSTERING COEFFICIENT :
# ------------------------
# Lowest 15 :
# feluda  mukul  jatayu  hajra  also  dr  rajasthan  fail  bose  try  first  take  burman  mandar  nt
#
# Highest 15 :
# various  reporter  nothing  misspell  yellow  word  whereas  villain  tire  three  suddenly  stop  state  soumitra  search

# %%
wordsByBetweennessCentrality(G)
# Out:
# BETWEENNESS CENTRALITY :
# ------------------------
# Lowest 15 :
# aka  alarmed  asleep  assignment  attempt  attention  audience  aware  barmer  coincidentally  complete  decides  exists  film  finally
#
# Highest 15 :
# mukul  feluda  hajra  dr  jatayu  also  take  bose  meet  try  burman  mandar  first  rajasthan  gem

# %%
wordsByDegreeCentrality(G)
# Out:
# DEGREE CENTRALITY :
# -------------------
# Lowest 15 :
# aka  alarmed  attempt  attention  audience  aware  barmer  coincidentally  complete  exists  film  finally  hand  identity  injury
#
# Highest 15 :
# mukul  feluda  hajra  dr  burman  jatayu  take  bose  also  mandar  try  gem  rajasthan  meet  fort

# %%
#################################### Betweenness Centrality ##########################################
BC_dict=dict(nx.betweenness_centrality(G))

nodesizearray=[]
for n in G.nodes:
	nodesizearray.append(10000*BC_dict[n])

figure(num=None, figsize=(50, 50), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(121)
nx.draw(G,node_size=nodesizearray, with_labels=True, font_weight='bold')
######################################################################################################

# %%
###################################   Degree Centrality Plot  ########################################
de_dict=dict(nx.degree_centrality(G))

nodesizearray=[]
for n in G.nodes:
	nodesizearray.append(10000*de_dict[n])

figure(num=None, figsize=(50, 50), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(121)
nx.draw(G,node_size=nodesizearray, with_labels=True, font_weight='bold')
######################################################################################################
